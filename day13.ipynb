# %% [markdown]
# ## Dictionary

# %% [markdown]
# (we can declare any key in dictionary)
# in list-
# ![image.png](attachment:image.png)
#
#
# in case of list:
# if size of key is 1000 we need at least 1001 values in the list.
# ![image-2.png](attachment:image-2.png)

# %%
a={}
type(a)
# Out:
# dict

# %%
# key : value
a= {'a':100 , 2:50}
a
# Out:
# {'a': 100, 2: 50}

# %%
b = a.copy()
b
# Out:
# {'a': 100, 2: 50}

# %%
b =a
b
# Out:
# {'a': 100, 2: 50}

# %% [markdown]
# #### 2 format of passing dict

# %%
# c= dict()
#c= dict([inside this give key val. pairs])
#c= dict([(,),(,),(,)])
c= dict([('a',4),(6,8),('k','u')])
c
# Out:
# {'a': 4, 6: 8, 'k': 'u'}

# %% [markdown]
# #### 3 format of passing dict

# %%
d= dict.fromkeys(['abc',4,5])
d
# Out:
# {'abc': None, 4: None, 5: None}

# %%
d= dict.fromkeys(['abc',4,5],10)
d
# Out:
# {'abc': 10, 4: 10, 5: 10}

# %%
d = dict.fromkeys(['abc', 4, 5])

# Assign different values to specific keys
d['abc'] = 20
d[4] = 30
d[5] = 40

# Print the dictionary
print(d)
# Out:
# {'abc': 20, 4: 30, 5: 40}

# %% [markdown]
# ### Changes in dict.

# %% [markdown]
# ![image.png](attachment:image.png)
# ..
# ![image-2.png](attachment:image-2.png)
#
# ///////////
# ////////
# ![image-3.png](attachment:image-3.png)
#
# ///////////
# ////////
#
# ![image-4.png](attachment:image-4.png)

# %%
# 77 isn't printed 
l = a.get('li',0)
m= a.get(list ,77)
print(l,m)
# Out:
# 0 77

# %%
a.get(list)

# %%
a.get("li")
print(a.get("li"))
# Out:
# None

# %%
# to check if a key exist

a={list:[1,2,3] , 1:5}
x= list in a 
x
# Out:
# True

# %%
a.keys()
# Out:
# dict_keys([<class 'list'>, 1])

# %%
a.items()
# Out:
# dict_items([(<class 'list'>, [1, 2, 3]), (1, 5)])

# %%
a.values()
# Out:
# dict_values([[1, 2, 3], 5])

# %%
## Adding or deleting  values.

# %%
a
# Out:
# {list: [1, 2, 3], 1: 5}

# %%
a['t']= 1,5,8

# %%
a
# Out:
# {list: [1, 2, 3], 1: 5, 't': (1, 5, 8)}

# %%
b = {list:[1,7]  , 'a':1  }

# %%
# a will have same values except
# values same in b and a , then b  values will override.
# new values of b will be added.

a.update(b)

# %%
a
# Out:
# {list: [1, 7], 1: 5, 't': (1, 5, 8), 'a': 1}

# %%
a.pop('t')
# Out:
# (1, 5, 8)

# %%
a
# Out:
# {list: [1, 7], 1: 5, 'a': 1}

# %%
del a[1]

# %%
a
# Out:
# {list: [1, 7], 'a': 1}

# %%
a.clear
# Out:
# <function dict.clear>

# %%
a.clear()

# %%
a
# Out:
# {}

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
## print words with frequency K

s = 'this is a word string having many words'
k= 2

# %%
words = s.split()

# %%
d={}

for w in words:
    if w in d:
        d[w]+=1
    else:
        d[w]=1
d
# Out:
# {'this': 1,
#  'is': 1,
#  'a': 1,
#  'word': 1,
#  'string': 1,
#  'having': 1,
#  'many': 1,
#  'words': 1}

# %%
## or
s = 'this is a word string having many words'
k= 2

words = s.split()

d={}

for w in words:
     d[w]= d.get(w,0)+1
    
d
# Out:
# {'this': 1,
#  'is': 1,
#  'a': 1,
#  'word': 1,
#  'string': 1,
#  'having': 1,
#  'many': 1,
#  'words': 1}

# %% [markdown]
# ## Sets - collectionns of data without ordering
#
# <u>Set items are unchangeable, but you can remove items and add new items.</u>

# %%
a= {'abc',2,True}
a
# Out:
# {2, True, 'abc'}

# %%
# no indexing
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # no indexing
# ----> 2 a[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# no indexing
a['abc']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # no indexing
# ----> 2 a['abc']
#
# TypeError: 'set' object is not subscriptable

# %%
# In 
'abc' in  a
# Out:
# True

# %%
for  x in a:
    print (x)
# Out:
# True
# 2
# abc

# %%
len(a)
# Out:
# 3

# %%
a = {2, True, 'abc'}

# %% [markdown]
# ### Adding data in sets.

# %%
a.add('gg')

# %%
a
# Out:
# {2, True, 'abc', 'gg'}

# %%
b = {99,2}
b
# Out:
# {2, 99}

# %%
a.update(b)
a
# Out:
# {2, 99, True, 'abc', 'gg'}

# %% [markdown]
# ## Doubt
#
# why 1 was't added but others are getting added to updated a
#
# 1.
# ![image-2.png](attachment:image-2.png)
#
# 2.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ans
# 1== true in python.
# ![image.png](attachment:image.png)

# %%
# remove element if there is not that element, it shows error.
# discard don't shows any such error.
a
# Out:
# {2, 99, True, 'abc', 'gg'}

# %%
a.remove(2)

# %%
a
# Out:
# {99, True, 'abc', 'gg'}

# %%
a.remove('kuyf')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a.remove('kuyf')
#
# KeyError: 'kuyf'

# %%
a.discard('not in set')
#no error

# %%
# removes element , which  index(dont exist) don't know, hence any element removed 
a.pop()
# Out:
# True

# %%
a
# Out:
# {99, 'abc', 'gg'}

# %%
a.pop()
# Out:
# 'gg'

# %%
a
# Out:
# {99, 'abc'}

# %%
a.clear()

# %%
a
# Out:
# set()

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## operations

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
s

# %% [markdown]
# Problem- sum of unique numbers.
#
#
# ![image.png](attachment:image.png)
