# %%
# Linear search
ele = int(input())

is_found = False
for i in range(len(li)) :
    if li[i] == ele:
        print ('index is',i)
        print ('element is ',li[i]) 
        is_found= True 
        break
if is_found is False:
        print (-1)
# Out:
# 3
# index is 2
# element is  3

# %%
li = [int(x) for x in input().split()]

ele = int(input())

is_found = False
for i in range(len(li)) :
    if li[i] == ele:
        print ('index is',i)
        print ('element is ',li[i]) 
        is_found= True 
        break
if is_found is False:
        print ('element not present in list')
# Out:
# 1 2 3 4
# 3
# index is 2
# element is  3

# %% [markdown]
# # Mutable and non mutable concept

# %%
# mutable can bechange
a =3
x= a 
    
id(a)
# Out:
# 1982479925552

# %%
id(x)
# Out:
# 1982479925552

# %%
x  =5
id (x)
# Out:
# 1982479925616

# %% [markdown]
# Value of variable in memory are Immutable -                         Reference of memory changes not values
# ![image.png](attachment:image.png)

# %%
li = [1,2,3,4]
li2 = li
li2[1] = 0
li
# Out:
# [1, 0, 3, 4]

# %% [markdown]
# This is mutable (Lists are mutable oin python)- li and li2 both have same adress thet is why li is also changs even thought we chnaged only li2
# ![image.png](attachment:image.png)

# %%
li = [1,2,3,4]
li2 = li
li2= [6,7,8,9]
li2[1] = 0
li
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# no change here  bcz new list is ccreated at new address ![image.png](attachment:image.png)
