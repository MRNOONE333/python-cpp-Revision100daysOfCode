# %% [markdown]
# ## 8 september  Lists and Arrays

# %%
# arrays are homogeneous and lists are heterogeneous

# %%
# List  create , access  , append .

# %%
li = []
li
# Out:
# []

# %%
li= [1,3,3,'ahad',7]

# %%
li
# Out:
# [1, 3, 3, 'ahad', 7]

# %%
li [1]= 0

# %%
li
# Out:
# [1, 0, 3, 'ahad', 7]

# %%
li[4]
# Out:
# 7

# %%
#Slicing

# %%
li[:]
# Out:
# [1, 0, 3, 'ahad', 7]

# %%
li[1:]
# Out:
# [0, 3, 'ahad', 7]

# %%
li[1:3]
# gave from 1 till 2 Index
# Out:
# [0, 3]

# %% [markdown]
# ## Insert and append

# %%
li.insert(0,9)

# %%
li
# Out:
# [9, 9, 1, 0, 3, 'ahad', 7]

# %%
li.append(0)

# %%
li
# Out:
# [9, 9, 1, 0, 3, 'ahad', 7, 0]

# %%
# append inserts at last index.

# %%
li.append([1,3,4])
li
# Out:
# [9, 9, 1, 0, 3, 'ahad', 7, 0, [1, 3, 4]]

# %%
li.extend([8,9,0])

# %%
li
# Out:
# [9, 1, 0, 3, 'ahad', 7, 0, [1, 3, 4], 8, 9, 0]

# %% [markdown]
# ## removing elements from list

# %%
li
# Out:
# [9, 1, 0, 3, 'ahad', 7, 0, [1, 3, 4], 8, 9, 0]

# %%
li.remove(9)
# this isremoving element 9 not at the index.

# %%
li
# Out:
# [9, 1, 0, 3, 'ahad', 7, 0, [1, 3, 4], 8, 9, 0]

# %%
li.remove(9)

# %%
li
# Out:
# [1, 0, 3, 'ahad', 7, 0, [1, 3, 4], 8, 9, 0]

# %%
# li.remove only removes one element at once.

# %%
li.pop()
# Out:
# 0

# %%
li
# Out:
# [1, 0, 3, 'ahad', 7, 0, [1, 3, 4], 8, 9]

# %%
li.pop()
# Out:
# 9

# %%
li
# Out:
# [1, 0, 3, 'ahad', 7, 0, [1, 3, 4], 8]

# %%
# li .pop removes last element by defauult.

# %%
li.pop(3)
# Out:
# 'ahad'

# %%
li
# Out:
# [1, 0, 3, 7, 0, [1, 3, 4]]

# %%
len(li)
# Out:
# 6

# %%
# list stores addresses/references of elements continuously .
#100,104,108,112 simillarlt....

# %% [markdown]
# ![Screenshot%202023-09-08%20105652.png](attachment:Screenshot%202023-09-08%20105652.png)

# %% [markdown]
# # Resizing of list (addresses/references of elements are changes)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Looping in lists

# %%
li = [1,5,9]
li
# Out:
# [1, 5, 9]

# %%
for i in range (len(li)):
    print (li[i])
# Out:
# 1
# 5
# 9

# %%
li.extend(['name',4])
li
# Out:
# [1, 5, 9, 'name', 4]

# %%
li
# Out:
# [1, 5, 9, 'name', 4]

# %%
for i in range (2,len(li)):
    print (li[i])
# Out:
# 9
# name
# 4

# %%
# Slicing
for x in li[2:]:
    print(x)
# Out:
# 9
# name
# 4

# %% [markdown]
# ## Negative Indexing

# %%
li= [1,2,3,4,5,6,7,8,9,0]

# %%
li[-5]
# Out:
# 6

# %%
li[-1]
# Out:
# 0

# %% [markdown]
# ## Sequencing

# %%
# li[start: end +1 :step ]
li[1:8:1]
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
li[::]
# if end +1 isn't defined it will go till end of list.
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
li[::2]
# Out:
# [1, 3, 5, 7, 9]

# %%
li[1:8:2]
# Out:
# [2, 4, 6, 8]

# %%
li[-4:-1:1]
# Out:
# [7, 8, 9]

# %% [markdown]
# ## list separate values.

# %%
n = int(input())

for x in range(n):
    current = int(input())
    li.append(current)
# Out:
# 5
# 1
# 3
# 6
# 8
# 00

# %%
for i in range (len(li)):
    print(li[i])
# line separated input.
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0
# 1
# 3
# 6
# 8
# 0

# %% [markdown]
# ## `Space separated input

# %%
# giving a space separated input.
str = input()
# Out:
# 1 2 3 4 5

# %%
str_split = str.split(' ')

# %%
str
# Out:
# '1 2 3 4 5'

# %%
str_split
# Out:
# ['1', '2', '3', '4', '5']

# %%
str = input()
# Out:
# 1,2,3,4,5

# %%
str_split = str.split(',')

# %%
str_split
# Out:
# ['1', '2', '3', '4', '5']

# %%
# one way for Space separated input
li = []
for x in str_split:
    li.append(int(x))

# %%
li
# Out:
# [1, 2, 3, 4, 5]

# %%
# here i don't need to specify split against ,  or ' ' or anything , see cell xx1
li2 = [int(x) for x in input().split()]
# Out:
# 1 2 3 4 5

# %%
li2
# Out:
# [1, 2, 3, 4, 5]

# %%
for x in li2:
    print (x)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# All together
# 2nd way for Space separated input
li2 = [int(x) for x in input().split()] 
for x in li:
    print (x)
# Out:
# 1 2 3 4
# 1
# 2
# 3
# 4
# 5

# %%
# but this shows error in  
li2 = [int(x) for x in input().split()] 
for x in li:
    print (x)
# Out:
#  1,2,3 4 5 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 2
#       1 # but this shows error in
# ----> 2 li2 = [int(x) for x in input().split()]
#       3 for x in li:
#       4     print (x)
#
# Cell In[102], line 2, in <listcomp>(.0)
#       1 # but this shows error in
# ----> 2 li2 = [int(x) for x in input().split()]
#       3 for x in li:
#       4     print (x)
#
# ValueError: invalid literal for int() with base 10: '1,2,3'

# %%
#xx1
li3 = [int(x) for x in input().split(',')] 
# give input as 1 2 3 4 it will show error.
# Out:
# 1 2 3 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 li3 = [int(x) for x in input().split(',')]
#
# Cell In[94], line 1, in <listcomp>(.0)
# ----> 1 li3 = [int(x) for x in input().split(',')]
#
# ValueError: invalid literal for int() with base 10: '1 2 3 4 '

# %%
li3
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## Doubt

# %% [markdown]
# If it has given error in first line then why is it printing li3 ?? it should have caused error.
# ![image.png](attachment:image.png)

# %%
li = [int(x) for x in input().split()]
# Out:
# 1 2 3 4 5

# %%
li
# Out:
# [1, 2, 3, 4, 5]
