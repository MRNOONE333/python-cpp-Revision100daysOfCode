# %% [markdown]
# ## More on loopps

# %% [markdown]
# in a loops :-
# ![image.png](attachment:image.png)

# %%
n = int(input())
for i in range (1,n+1,2): #jump of 2
    print(i)
# Out:
# 8
# 1
# 3
# 5
# 7

# %%
n = int(input())
for i in range (n+1): #jump of 2
    print(i)
# Out:
# 8
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
# assumption a<b

a = int(input())
b = int(input())

x=1
for n in range (a, b+1) :
    if n % 3 == 0 :
        print (n)
# Out:
# 2
# 18
# 3
# 6
# 9
# 12
# 15
# 18

# %%
# check if a no. is prime

n  = int(input())

flag = False
for x in range (2,n):
    if n%x==0:
        flag = True

if flag:
    print('not prime')
else:
    print('prime')
# Out:
# 7
# prime
