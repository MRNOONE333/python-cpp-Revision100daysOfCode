# %% [markdown]
# # patterns day3

# %%
n = int(input())
i=1
while i<=n:
    j=1
    while j<=n:
        print('*')
        j=j+1
    print()
    i=i+1
    
# Enter by default.
# Out:
# 2
# *
# *
#
# *
# *

# %%
n = int(input())
i=1
while i<=n:
    j=1
    while j<=n:
        print('*',end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# ****
# ****
# ****
# ****

# %%
n = int(input())

i=1
while (i<=n): 
    j=1
    while(j<=i):
        print('*' , end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# *
# **
# ***
# ****

# %%
n = int(input())
i=1
while i<=n:
    j=1
    while j<=n:
        print('*',end='')
        j=j+1
    print()
    i=i+1
# Out:
# 3
# ***
# ***
# ***

# %% [markdown]
# ### For printing any pattern.
# 1-NO.of rows
# 2-NO.of column
# 3-what to print.
# ![image.png](attachment:image.png)

# %%
n= int(input())

i = 1
while i<= n :
    j= 1
    while j<=n:
        j=j+1
        print(i, end= '')
    print()
    i = i+1
# Out:
# 4
# 1111
# 2222
# 3333
# 4444

# %%
n= int(input())

i = 1
while i<= n :
    j= 1
    while j<=n:
        print(j, end= '')
        j=j+1
    print()
    i = i+1
# Out:
# 4
# 1234
# 1234
# 1234
# 1234

# %%
n= int(input())

i = 1
while i<= n :
    j= 1
    while j<=n:
        print(n-j +1, end= '')
        j=j+1
    print()
    i = i+1
# Out:
# 4
# 4321
# 4321
# 4321
# 4321

# %%
n = int(input())

i =1
while i<=n:
    j=1
    while j<=i:
        print(j,end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# 1
# 12
# 123
# 1234

# %%
n = int(input())

i =1
while i<=n:
    j=1
    while j<=i:
        print(i+j-1,end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# 1
# 23
# 345
# 4567

# %%
ord('a')
# Out:
# 97

# %%
chr(101)
# Out:
# 'e'

# %%
n = int(input())
# a = ord('a')
print(ord('a') + n -1 )
print(chr(ord('a') + n -1 ))
# Out:
# 4
# 100
# d

# %%
n = int(input())

i = 1
while i<=n:
    j=1
    while j<=n:
        print(chr(97+j-1),end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# abcd
# abcd
# abcd
# abcd

# %%
# something great  without using 3rd varible

n = int(input())

i = 1
while i<=n:
    j=1
    while j<=n:
        print(chr(ord(chr(ord('a')+i-1))+j-1),end='')
        j=j+1
    print()
    i=i+1
# Out:
# 4
# abcd
# bcde
# cdef
# defg
